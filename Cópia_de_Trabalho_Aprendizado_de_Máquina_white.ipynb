# %% [markdown]
# Bibliotecas

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# carregando datasets (umm dataset contém dados de vinho branco e outro de vinho tinto)

# %%
# carregando datasets (vinho branco)
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", sep=';')

print("White wine shape:", df.shape)

df.head()
# Out:
# White wine shape: (4898, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# Removendo duplicatas

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (3961, 12)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# ...

# %% [markdown]
# Normalização min-max

# %%
df_norm = (df - df.min()) / (df.max() - df.min())
df_norm.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        0.292245          0.196606     0.201405        0.081516
# std         0.083352          0.101409     0.073763        0.074565
# min         0.000000          0.000000     0.000000        0.000000
# 25%         0.240385          0.127451     0.162651        0.015337
# 50%         0.288462          0.176471     0.192771        0.062883
# 75%         0.336538          0.245098     0.234940        0.127301
# max         1.000000          1.000000     1.000000        1.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.109511             0.114596              0.297433     0.128774
# std       0.068554             0.059965              0.100067     0.055998
# ...

# %% [markdown]
# gráfico do desvio padrão de cada atributo

# %%
# desvio padrão de cada coluna
desvio_padrao = df_norm.std()

# criando o gráfico
plt.figure(figsize=(10, 6))
desvio_padrao.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Desvio Padrão dos Atributos', fontsize=14)
plt.xlabel('Atributos', fontsize=12)
plt.ylabel('Desvio Padrão', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# distribuição dos vinhos brancos
plt.figure(figsize=(8,4))
plt.hist(df["quality"], bins=range(2,10), edgecolor="black", color="gold")
plt.title("Distribuição das notas de qualidade - Vinho Branco")
plt.xlabel("Qualidade")
plt.ylabel("Frequência")
plt.grid(axis="y", alpha=0.3)
plt.show()

# %% [markdown]
# Correlação (heatmap)

# %%
# correlação geral
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt='.2f')
plt.title('Mapa de correlação')
plt.show()


# correlação ordenada com o atributo alvo 'quality'
print("\nCorrelação com a variável alvo (quality):")
print(corr["quality"].sort_values(ascending=False))
# Out:
# Correlação com a variável alvo (quality):
# quality                 1.000000
# alcohol                 0.462869
# pH                      0.123829
# sulphates               0.053200
# free sulfur dioxide     0.010507
# citric acid             0.007065
# residual sugar         -0.117339
# fixed acidity          -0.124636
# total sulfur dioxide   -0.183356
# volatile acidity       -0.190678
# chlorides              -0.217739
# density                -0.337805
# Name: quality, dtype: float64

# %% [markdown]
# Gráficos boxplot (com os dados normalizados dá na mesma)

# %%
# lista de atributos (excluindo a target e a coluna 'type')
features = [col for col in df.columns if col not in ['quality']]

# gera um boxplot para cada atributo (x)
plt.figure(figsize=(14, 10))
for i, col in enumerate(features, 1):
    plt.subplot(4, 3, i)
    sns.boxplot( y=col, data=df)
    plt.title(col)
    plt.tight_layout()
plt.show()

# %% [markdown]
# Binarizando o atributo alvo (quality)

# %%
# binarizando com limiar = 6
df['quality_binary'] = (df['quality'] >= 6).astype(int)

# contagem absoluta
print(df['quality_binary'].value_counts())

# contagem com proporções
print(df['quality_binary'].value_counts(normalize=True))

# total de instâncias
print("Total:", df['quality_binary'].shape[0])
# Out:
# quality_binary
# 1    2613
# 0    1348
# Name: count, dtype: int64
# quality_binary
# 1    0.659682
# 0    0.340318
# Name: proportion, dtype: float64
# Total: 3961

# %% [markdown]
# Remoção de outliers

# %%
# remoção de outliers
num_cols = df.select_dtypes(include='number').columns

mask = pd.Series(True, index=df.index)

for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    mask &= (df[col] >= lower) & (df[col] <= upper)

df_filtered = df[mask]


# contagem absoluta
print(df['quality_binary'].value_counts())

# contagem com proporções
print(df['quality_binary'].value_counts(normalize=True))

# total de instâncias
print("Total:", df['quality_binary'].shape[0])
# Out:
# quality_binary
# 1    2613
# 0    1348
# Name: count, dtype: int64
# quality_binary
# 1    0.659682
# 0    0.340318
# Name: proportion, dtype: float64
# Total: 3961

# %% [markdown]
# Boxplots pós remoção de outliers

# %%
# lista de atributos (excluindo a target e a coluna 'type')
features = [col for col in df.columns if col not in ['quality']]

# gera um boxplot para cada atributo (x)
plt.figure(figsize=(14, 10))
for i, col in enumerate(features, 1):
    plt.subplot(4, 3, i)
    sns.boxplot( y=col, data=df)
    plt.title(col)
    plt.tight_layout()
plt.show()

# %% [markdown]
# Remoção dos atributos 'density' e 'total sulfur dioxide'

# %%
df = df.drop(columns=['density', 'total sulfur dioxide'])

# %% [markdown]
# normalização + SMOTE + modelo -> com 5-fold cross-validation estratificado

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

# separa features e target
X = df.drop(columns=['quality', 'quality_binary'])
y = df['quality_binary']

modelos = {
    "Regressão Logística": LogisticRegression(max_iter=200),
    "Árvore de Decisão": DecisionTreeClassifier(),
    "MLP": MLPClassifier(max_iter=500),
    "Naive Bayes": GaussianNB(),
    "KNN": KNeighborsClassifier()
}

# k-fold estratificado
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=37)

# função p/ rodar spot-checking
def avaliar_modelos(modelos):
    resultados = {}

    for nome, modelo in modelos.items():

        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('smote', SMOTE(random_state=37)),
            ('model', modelo)
        ])

        accuracy_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='accuracy')
        f1_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='f1')
        precision_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='precision')
        recall_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='recall')
        roc_auc_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='roc_auc')

        resultados[nome] = {
            "Accuracy":  (accuracy_scores.mean(), accuracy_scores.std()),
            "F1":        (f1_scores.mean(), f1_scores.std()),
            "Precision": (precision_scores.mean(), precision_scores.std()),
            "Recall":    (recall_scores.mean(), recall_scores.std()),
            "Roc_Auc":   (roc_auc_scores.mean(), roc_auc_scores.std()),

            # valores brutos para gráficos
            "Accuracy_raw": accuracy_scores,
            "F1_raw": f1_scores,
            "Precision_raw": precision_scores,
            "Recall_raw": recall_scores,
            "Roc_Auc_raw": roc_auc_scores
        }

        print(f"\n=== {nome} ===")
        print(f"Accuracy médio:  {accuracy_scores.mean():.4f} (± {accuracy_scores.std():.4f})")
        print(f"F1 médio:        {f1_scores.mean():.4f} (± {f1_scores.std():.4f})")
        print(f"Precisão média:  {precision_scores.mean():.4f} (± {precision_scores.std():.4f})")
        print(f"Recall médio:    {recall_scores.mean():.4f} (± {recall_scores.std():.4f})")
        print(f"ROC AUC médio:   {roc_auc_scores.mean():.4f} (± {roc_auc_scores.std():.4f})")

    return resultados

resultados = avaliar_modelos(modelos)
# Out:
# === Regressão Logística ===
# Accuracy médio:  0.7228 (± 0.0119)
# F1 médio:        0.7725 (± 0.0084)
# Precisão média:  0.8426 (± 0.0158)
# Recall médio:    0.7134 (± 0.0082)
# ROC AUC médio:   0.7999 (± 0.0185)
#
# === Árvore de Decisão ===
# Accuracy médio:  0.6938 (± 0.0109)
# F1 médio:        0.7654 (± 0.0077)
# Precisão média:  0.7784 (± 0.0154)
# Recall médio:    0.7443 (± 0.0113)
# ROC AUC médio:   0.6710 (± 0.0179)
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
# !pip install joypy
import seaborn as sns
import joypy

# lista para armazenar registros individuais
linhas = []

for modelo, metricas in resultados.items():
    for i in range(5):  # 5 folds da validação cruzada
        linhas.append({
            "Modelo": modelo,
            "Accuracy":  metricas["Accuracy_raw"][i]  if "Accuracy_raw"  in metricas else None,
            "F1":        metricas["F1_raw"][i]        if "F1_raw"        in metricas else None,
            "Precision": metricas["Precision_raw"][i] if "Precision_raw" in metricas else None,
            "Recall":    metricas["Recall_raw"][i]    if "Recall_raw"    in metricas else None,
            "Roc_Auc":   metricas["Roc_Auc_raw"][i] if "Roc_Auc_raw"   in metricas else None
        })

df_scores = pd.DataFrame(linhas)

# %% [markdown]
# Boxplot das métricas

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df_scores, x="Modelo", y="Accuracy")
plt.title("Distribuição da Accuracy por Modelo")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.boxplot(data=df_scores, x="Modelo", y="F1")
plt.title("Distribuição do F1-score por Modelo")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.boxplot(data=df_scores, x="Modelo", y="Precision")
plt.title("Distribuição da Precisão por Modelo")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.boxplot(data=df_scores, x="Modelo", y="Recall")
plt.title("Distribuição do Recall por Modelo")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.boxplot(data=df_scores, x="Modelo", y="Roc_Auc")
plt.title("Distribuição do ROC AUC por Modelo")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Violin Plot das métricas

# %%
# VIOLIN PLOTS PARA TODAS AS MÉTRICAS

plt.figure(figsize=(14, 8))
sns.violinplot(data=df_scores, x="Modelo", y="Accuracy", inner="quartile")
plt.title("Distribuição da Accuracy (Violin Plot)")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.violinplot(data=df_scores, x="Modelo", y="F1", inner="quartile")
plt.title("Distribuição do F1-score (Violin Plot)")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.violinplot(data=df_scores, x="Modelo", y="Precision", inner="quartile")
plt.title("Distribuição da Precisão (Violin Plot)")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.violinplot(data=df_scores, x="Modelo", y="Recall", inner="quartile")
plt.title("Distribuição do Recall (Violin Plot)")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.violinplot(data=df_scores, x="Modelo", y="Roc_Auc", inner="quartile")
plt.title("Distribuição do ROC AUC (Violin Plot)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Joyplot do F1

# %%
plt.figure(figsize=(10, 6))
joypy.joyplot(
    df_scores,
    by="Modelo",
    column="F1",
    figsize=(12, 8),
    kind="kde",
    title="Distribuição do F1-score (Joyplot)"
)
plt.show()

# %% [markdown]
# Tabela de médias e desvios padrão

# %%
tabela_resumo = df_scores.groupby("Modelo").agg(["mean", "std"])
print(tabela_resumo)
# Out:
#                      Accuracy                  F1           Precision  \
#                          mean       std      mean       std      mean
# Modelo
# KNN                  0.713206  0.018745  0.763447  0.018005  0.836814
# MLP                  0.748042  0.010696  0.801426  0.015296  0.841631
# Naive Bayes          0.720525  0.012159  0.781232  0.010207  0.807711
# Regressão Logística  0.722795  0.013322  0.772521  0.009409  0.842601
# Árvore de Decisão    0.693761  0.012168  0.765418  0.008596  0.778355
#
#                                  Recall             Roc_Auc
#                           std      mean       std      mean       std
# Modelo
# KNN                  0.014026  0.702248  0.026597  0.780564  0.015686
# MLP                  0.008036  0.772287  0.021449  0.810050  0.012611
# Naive Bayes          0.010933  0.756614  0.016082  0.775150  0.016443
# Regressão Logística  0.017719  0.713360  0.009158  0.799885  0.020692
# ...
